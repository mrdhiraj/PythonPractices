# %%
import datetime

x = datetime.datetime.now()
print(x)

print(x.year)
print(x.strftime("%A"))
print(x.strftime("%j"))#Day of year
# Out:
# 2018-07-30 15:19:12.916444
# 2018
# Monday
# 211

# %%
x = datetime.datetime(2018, 6, 1)
print(x.strftime("%B"))
# Out:
# June

# %%
t = datetime.time(1, 2, 3)
print ('Time:',t)
print ('hour  :', t.hour)
print ('minute:', t.minute)
print ('second:', t.second)
print ('microsecond:', t.microsecond)
print ('tzinfo:', t.tzinfo)
t
# Out:
# Time: 01:02:03
# hour  : 1
# minute: 2
# second: 3
# microsecond: 0
# tzinfo: None
# datetime.time(1, 2, 3)

# %%
#arrange
import numpy as np
import pandas as pd
observation_dates = np.arange('2017-01-01', '2017-01-09', dtype='datetime64[D]')
observation_dates
# Out:
# array(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#        '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08'],
#       dtype='datetime64[D]')

# %%
#to_datetime
dts = list(map(pd.to_datetime, observation_dates))
dts
# Out:
# [Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-01-02 00:00:00'),
#  Timestamp('2017-01-03 00:00:00'),
#  Timestamp('2017-01-04 00:00:00'),
#  Timestamp('2017-01-05 00:00:00'),
#  Timestamp('2017-01-06 00:00:00'),
#  Timestamp('2017-01-07 00:00:00'),
#  Timestamp('2017-01-08 00:00:00')]

# %%
Ufo=pd.read_csv('http://bit.ly/uforeports')
Ufo['Time']=pd.to_datetime(Ufo.Time)
Ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
Ufo['Year']=Ufo.Time.dt.year
Ufo.Year.value_counts().sort_index().plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
t = pd.DatetimeIndex(['2018-2-05'])
print(t[0].month,t[0].day,t[0].dayofyear)
# Out:
# 2 5 36
