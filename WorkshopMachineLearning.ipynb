# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\mldata\column_2C_weka.csv")

# %%
data
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 0           63.027818            22.552586              39.609117
# 1           39.056951            10.060991              25.015378
# 2           68.832021            22.218482              50.092194
# 3           69.297008            24.652878              44.311238
# 4           49.712859             9.652075              28.317406
# 5           40.250200            13.921907              25.124950
# 6           53.432928            15.864336              37.165934
# 7           45.366754            10.755611              29.038349
# 8           43.790190            13.533753              42.690814
# 9           36.686353             5.010884              41.948751
# 10          49.706610            13.040974              31.334500
# 11          31.232387            17.715819              15.500000
# 12          48.915551            19.964556              40.263794
# ...

# %%
data.head()
# Out:
#    pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
data.describe()
# Out:
#        pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# count        310.000000           310.000000             310.000000
# mean          60.496653            17.542822              51.930930
# std           17.236520            10.008330              18.554064
# min           26.147921            -6.554948              14.000000
# 25%           46.430294            10.667069              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.877696            22.120395              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# ...

# %%
color_list=["green" if i != "Abnormal" else "red" for i in data.loc[:,"class"]]

# %%
plt.plotting.scatter_matix(data.loc[:,data.columns!= "class"],flagsize=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cd91b7f20c4d> in <module>()
# ----> 1 plt.plotting.scatter_matix(data.loc[:,data.columns!= "class"],flagsize=3)
#
# AttributeError: 'function' object has no attribute 'scatter_matix'

# %%
sns.countplot(data.loc[:,'class'])
plt.show()
data.loc[:,'class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x,y=data.loc[:,data.columns!="class"],data.loc[:,"class"]

# %%
x_train,x_test,y_train,y_test=train_test_split)(x,y,test_size=0.3,random_state=1)
# Out:
#   File "<ipython-input-21-419fea2383c0>", line 1
#     x_train,x_test,y_train,y_test=train_test_split)(x,y,test_size=0.3,random_state=1)
#                                                   ^
# SyntaxError: invalid syntax

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn,fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-adaf30445fd7> in <module>()
# ----> 1 knn,fit(x_train,y_train)
#
# NameError: name 'fit' is not defined

# %%
y_predict=knn.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6a64a77602e4> in <module>()
# ----> 1 y_predict=knn.predict(x_test)
#
# NameError: name 'x_test' is not defined
